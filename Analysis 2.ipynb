# %%
import pandas as pd
import numpy as np
from scipy import stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
dd = pd.read_csv("Used_Car_Analysis")

# %% [markdown]
# ## 1) Can you tell me No of Vehicles by Brand Available on ebay for sale with the help of visualization.

# %%
dd['brand'].value_counts().plot(kind = 'bar', xlabel = 'Brand Names', ylabel = 'Count of Vehicles')
# Out:
# <Axes: xlabel='Brand Names', ylabel='Count of Vehicles'>

# %% [markdown]
# ## 2) What is the Average price for vehicles based on the type of vehicle as well as on the type of gearbox.Explain me with both numerical and visualization analysis.

# %%
pd.crosstab(dd['vehicleType'],dd["gearbox"],values=dd['price'], aggfunc = 'mean')
# Out:
# gearbox         automatik       manuell
# vehicleType
# andere        8963.811060   4291.629873
# bus          11111.818360   6187.203371
# cabrio       16148.505927   8977.921948
# coupe        16414.075651  10429.020841
# kleinwagen    4276.086465   3161.149184
# kombi         9299.356506   5174.277380
# limousine    10182.468528   4965.362099
# suv          17278.553939  10456.736365

# %%
pd.crosstab(dd['vehicleType'],dd["gearbox"],values=dd['price'], aggfunc = 'mean').plot(kind = 'bar', xlabel = "Type Of Vehicle", ylabel = "Average Price Range")
# Out:
# <Axes: xlabel='Type Of Vehicle', ylabel='Average Price Range'>

# %% [markdown]
# ## 3) What is the marginal probability of private seller.

# %%
dd['seller'].value_counts()/len(dd)
# Out:
# privat        0.999993
# gewerblich    0.000007
# Name: seller, dtype: float64
